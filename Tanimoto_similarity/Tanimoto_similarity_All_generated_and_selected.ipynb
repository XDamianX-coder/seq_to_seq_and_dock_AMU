# %%
from rdkit import Chem
from rdkit.DataStructs.cDataStructs import TanimotoSimilarity
from rdkit.Chem.MolStandardize import rdMolStandardize
import pubchempy as pcp
import pandas as pd
import matplotlib.pyplot as plt

# %%
initial_smi = pd.read_excel(r'../prediction_and_selection/Prediction_initializers_ROR_activ.xlsx')
initial_smi = list(initial_smi['SMILES'])
initial_smi = pd.DataFrame(initial_smi, columns=['SMILES'])
print("Initial data description: ")
print(initial_smi.describe())

print("SMILES used to predict new molecules description: ")
print(initial_smi.describe())

print("Examples of initial structures: ")
print(initial_smi[0:3])
# Out:
# Initial data description:
#                                                    SMILES
# count                                                   5
# unique                                                  5
# top     CC(=O)Nc1ccc2c(c1)CCCN2Cc1ccc(C(O)(C(F)(F)F)C(...
# freq                                                    1
# SMILES used to predict new molecules description:
#                                                    SMILES
# count                                                   5
# unique                                                  5
# top     CC(=O)Nc1ccc2c(c1)CCCN2Cc1ccc(C(O)(C(F)(F)F)C(...
# freq                                                    1
# Examples of initial structures:
#                                               SMILES
# 0               CCC(=O)Nc1ccc2nn(-c3ccc(CC)cc3)nc2c1
# 1                Cc1cccc(C(=O)Nc2cc(-c3ccccc3)no2)c1
# 2  CC(=O)N1CCN(Cc2ccc(-c3ccc(C(O)(C(F)(F)F)C(F)(F...

# %%
output_smi = pd.read_excel(r'../prediction_and_selection/All_generated_SMILES_QED_Lipinski.xlsx')
output_smi = list(output_smi['SMILES'])
docked_mols = output_smi
output_smi[0:3]
# Out:
# ['CCC(=O)NCC1=CC=NN1S2C=C(C3=CC=CC=C3F)N[NH1]2',
#  'CCC(=O)N1CC2C(C#N)(S(=O)C3=CC=CC=N3)CC12',
#  'CCC(=O)N1C=2C=CN(C3=NC=NC(C#N)=C3C)C=2S1C']

# %%
initial_mol = [Chem.MolFromSmiles(smi) for smi in initial_smi['SMILES']]

# %%
output_smi = [Chem.MolFromSmiles(smi) for smi in output_smi]

# %%
output_smi[0]

# %%
largest_Fragment = rdMolStandardize.LargestFragmentChooser()
to_check_in_PUBCHEM = []
standarized_mols = []
for smi in output_smi:
    largest_mol = largest_Fragment.choose(smi) #Mol object is returned
    cannonical = Chem.MolToSmiles(largest_mol, isomericSmiles=False)
    standarized_mols.append(cannonical)
    to_check_in_PUBCHEM.append(cannonical)
standarized_mols[0:3]
# Out:
# [21:26:08] Running LargestFragmentChooser
# [21:26:08] Fragment: CCC(=O)NCc1ccnn1[SH]1C=C(c2ccccc2F)NN1
# [21:26:08] New largest fragment: CCC(=O)NCc1ccnn1[SH]1C=C(c2ccccc2F)NN1 (41)
# [21:26:08] Running LargestFragmentChooser
# [21:26:08] Fragment: CCC(=O)N1CC2C1CC2(C#N)S(=O)c1ccccn1
# [21:26:08] New largest fragment: CCC(=O)N1CC2C1CC2(C#N)S(=O)c1ccccn1 (35)
# [21:26:08] Running LargestFragmentChooser
# [21:26:08] Fragment: CCC(=O)N1c2ccn(-c3ncnc(C#N)c3C)c2[SH]1C
# [21:26:08] New largest fragment: CCC(=O)N1c2ccn(-c3ncnc(C#N)c3C)c2[SH]1C (36)
# [21:26:08] Running LargestFragmentChooser
# [21:26:08] Fragment: CCC(=O)NCC1=NN=C(c2ccc(C)c(CF)c2)SC1
# [21:26:08] New largest fragment: CCC(=O)NCC1=NN=C(c2ccc(C)c(CF)c2)SC1 (39)
# [21:26:08] Running LargestFragmentChooser
# [21:26:08] Fragment: CCC(=O)NCc1ccnn1S1=C(C)NC(c2ccccc2F)=C1
# [21:26:08] New largest fragment: CCC(=O)NCc1ccnn1S1=C(C)NC(c2ccccc2F)=C1 (43)
# [21:26:08] Running LargestFragmentChooser
# [21:26:08] Fragment: CCC(=O)NC1C=C2C=CC3CC=CC(=N3)N2C1C
# [21:26:08] New largest fragment: CCC(=O)NC1C=C2C=CC3CC=CC(=N3)N2C1C (38)
# [21:26:08] Running LargestFragmentChooser
# [21:26:08] Fragment: CCC(=O)NCc1ccnn1N1NC2=C(NO)C1CC2C
# [21:26:08] New largest fragment: CCC(=O)NCc1ccnn1N1NC2=C(NO)C1CC2C (41)
# [21:26:08] Running LargestFragmentChooser
# [21:26:08] Fragment: CCC(=O)NCC=C1C=CNC(Cc2n[nH]c3c2CCO3)=N1
# [21:26:08] New largest fragment: CCC(=O)NCC=C1C=CNC(Cc2n[nH]c3c2CCO3)=N1 (41)
# [21:26:08] Running LargestFragmentChooser
# [21:26:08] Fragment: CCC(=O)NCC1C(N)=NC1c1n[nH]cc1C(C)(C)O
# [21:26:08] New largest fragment: CCC(=O)NCC1C(N)=NC1c1n[nH]cc1C(C)(C)O (41)
# [21:26:08] Running LargestFragmentChooser
# [21:26:08] Fragment: CC(C1=CC=C[SH]1N)C1=NN=CC=CCNC(=O)CC1
# [21:26:08] New largest fragment: CC(C1=CC=C[SH]1N)C1=NN=CC=CCNC(=O)CC1 (40)
# [21:26:08] Running LargestFragmentChooser
# [21:26:08] Fragment: CCC(=O)NC1CC(c2n[nH]cc2C(C)=C=N)O1
# [21:26:08] New largest fragment: CCC(=O)NC1CC(c2n[nH]cc2C(C)=C=N)O1 (34)
# [21:26:08] Running LargestFragmentChooser
# [21:26:08] Fragment: CCC(=O)NCc1ccnn1S1=NNC(c2ccccc2F)=C1
# [21:26:08] New largest fragment: CCC(=O)NCc1ccnn1S1=NNC(c2ccccc2F)=C1 (39)
# [21:26:08] Running LargestFragmentChooser
# [21:26:08] Fragment: C=S(=O)(C(C)C)C1(C#N)C=NSN(C(=O)CC)CC1
# [21:26:08] New largest fragment: C=S(=O)(C(C)C)C1(C#N)C=NSN(C(=O)CC)CC1 (38)
# [21:26:08] Running LargestFragmentChooser
# [21:26:08] Fragment: Cc1cccc(C(=O)Cc2nc(Cl)cc3cccnc23)c1
# [21:26:08] New largest fragment: Cc1cccc(C(=O)Cc2nc(Cl)cc3cccnc23)c1 (34)
# [21:26:08] Running LargestFragmentChooser
# [21:26:08] Fragment: Cc1cccc(C(=O)Nc2cc(-c3ccccc3)no2)c1
# [21:26:08] New largest fragment: Cc1cccc(C(=O)Nc2cc(-c3ccccc3)no2)c1 (35)
# [21:26:08] Running LargestFragmentChooser
# [21:26:08] Fragment: Cc1cccc(C(=O)Cc2nc(Cc3ccco3)cs2)c1
# [21:26:08] New largest fragment: Cc1cccc(C(=O)Cc2nc(Cc3ccco3)cs2)c1 (36)
# [21:26:08] Running LargestFragmentChooser
# [21:26:08] Fragment: N#CCC1CCC2CCCN3CC=CC=CC=C1C2=CCOC#CNO3
# [21:26:08] New largest fragment: N#CCC1CCC2CCCN3CC=CC=CC=C1C2=CCOC#CNO3 (51)
# [21:26:08] Running LargestFragmentChooser
# [21:26:08] Fragment: N#CCC1CCC2CCCN3CC=CC=CC=C1C2=CCOC=CNO3
# [21:26:08] New largest fragment: N#CCC1CCC2CCCN3CC=CC=CC=C1C2=CCOC=CNO3 (53)
# [21:26:08] Running LargestFragmentChooser
# [21:26:08] Fragment: CNS(=O)(=O)N1CC2CCCC=Cc3ccccc3SC=CC=CC=CC2O1
# [21:26:08] New largest fragment: CNS(=O)(=O)N1CC2CCCC=Cc3ccccc3SC=CC=CC=CC2O1 (54)
# [21:26:08] Running LargestFragmentChooser
# [21:26:08] Fragment: CNON1CCCC2OC3OCCC(=CC=CC=CNC1)CCCCCC23
# [21:26:08] New largest fragment: CNON1CCCC2OC3OCCC(=CC=CC=CNC1)CCCCCC23 (62)
# [21:26:08] Running LargestFragmentChooser
# [21:26:08] Fragment: O=S1(=O)NCCCCCc2ccccc2SC=CC=CC=CC=C(Cl)CN1
# [21:26:08] New largest fragment: O=S1(=O)NCCCCCc2ccccc2SC=CC=CC=CC=C(Cl)CN1 (52)
# [21:26:08] Running LargestFragmentChooser
# [21:26:08] Fragment: O=C1CN(Cc2cccc(F)c2Nc2ncccn2)C(=O)c2cccc(c2)N1
# [21:26:08] New largest fragment: O=C1CN(Cc2cccc(F)c2Nc2ncccn2)C(=O)c2cccc(c2)N1 (44)
# [21:26:08] Running LargestFragmentChooser
# [21:26:08] Fragment: CC(=O)Nc1cccc(C(=O)N2Cc3ccccc3Nc3nc(C)nc(c3F)NN=C2C#N)c1
# [21:26:08] New largest fragment: CC(=O)Nc1cccc(C(=O)N2Cc3ccc
# RDKit INFO: [21:26:08] Running LargestFragmentChooser
# RDKit INFO: [21:26:08] Fragment: CCC(=O)NCc1ccnn1[SH]1C=C(c2ccccc2F)NN1
# RDKit INFO: [21:26:08] New largest fragment: CCC(=O)NCc1ccnn1[SH]1C=C(c2ccccc2F)NN1 (41)
# RDKit INFO: [21:26:08] Running LargestFragmentChooser
# RDKit INFO: [21:26:08] Fragment: CCC(=O)N1CC2C1CC2(C#N)S(=O)c1ccccn1
# RDKit INFO: [21:26:08] New largest fragment: CCC(=O)N1CC2C1CC2(C#N)S(=O)c1ccccn1 (35)
# RDKit INFO: [21:26:08] Running LargestFragmentChooser
# RDKit INFO: [21:26:08] Fragment: CCC(=O)N1c2ccn(-c3ncnc(C#N)c3C)c2[SH]1C
# RDKit INFO: [21:26:08] New largest fragment: CCC(=O)N1c2ccn(-c3ncnc(C#N)c3C)c2[SH]1C (36)
# RDKit INFO: [21:26:08] Running LargestFragmentChooser
# RDKit INFO: [21:26:08] Fragment: CCC(=O)NCC1=NN=C(c2ccc(C)c(CF)c2)SC1
# RDKit INFO: [21:26:08] New largest fragment: CCC(=O)NCC1=NN=C(c2ccc(C)c(CF)c2)SC1 (39)
# RDKit INFO: [21:26:08] Running LargestFragmentChooser
# RDKit INFO: [21:26:08] Fragment: CCC(=O)NCc1ccnn1S1=C(C)NC(c2ccccc2F)=C1
# RDKit INFO: [21:26:08] New largest fragment: CCC(=O)NCc1ccnn1S1=C(C)NC(c2ccccc2F)=C1 (43)
# RDKit INFO: [21:26:08] Running LargestFragmentChooser
# RDKit INFO: [21:26:08] Fragment: CCC(=O)NC1C=C2C=CC3CC=CC(=N3)N2C1C
# RDKit INFO: [21:26:08] New largest fragment: CCC(=O)NC1C=C2C=CC3CC=CC(=N3)N2C1C (38)
# RDKit INFO: [21:26:08] Running LargestFragmentChooser
# RDKit INFO: [21:26:08] Fragment: CCC(=O)NCc1ccnn1N1NC2=C(NO)C1CC2C
# RDKit INFO: [21:26:08] New largest fragment: CCC(=O)NCc1ccnn1N1NC2=C(NO)C1CC2C (41)
# RDKit INFO: [21:26:08] Running LargestFragmentChooser
# RDKit INFO: [21:26:08] Fragment: CCC(=O)NCC=C1C=CNC(Cc2n[nH]c3c2CCO3)=N1
# RDKit INFO: [21:26:08] New largest fragment: CCC(=O)NCC=C1C=CNC(Cc2n[nH]c3c2CCO3)=N1 (41)
# RDKit INFO: [21:26:08] Running LargestFragmentChooser
# RDKit INFO: [21:26:08] Fragment: CCC(=O)NCC1C(N)=NC1c1n[nH]cc1C(C)(C)O
# RDKit INFO: [21:26:08] New largest fragment: CCC(=O)NCC1C(N)=NC1c1n[nH]cc1C(C)(C)O (41)
# RDKit INFO: [21:26:08] Running LargestFragmentChooser
# RDKit INFO: [21:26:08] Fragment: CC(C1=CC=C[SH]1N)C1=NN=CC=CCNC(=O)CC1
# RDKit INFO: [21:26:08] New largest fragment: CC(C1=CC=C[SH]1N)C1=NN=CC=CCNC(=O)CC1 (40)
# RDKit INFO: [21:26:08] Running LargestFragmentChooser
# RDKit INFO: [21:26:08] Fragment: CCC(=O)NC1CC(c2n[nH]cc2C(C)=C=N)O1
# RDKit INFO: [21:26:08] New largest fragment: CCC(=O)NC1CC(c2n[nH]cc2C(C)=C=N)O1 (34)
# RDKit INFO: [21:26:08] Running LargestFragmentChooser
# RDKit INFO: [21:26:08] Fragment: CCC(=O)NCc1ccnn1S1=NNC(c2ccccc2F)=C1
# RDKit INFO: [21:26:08] New largest fragment: CCC(=O)NCc1ccnn1S1=NNC(c2ccccc2F)=C1 (39)
# RDKit INFO: [21:26:08] Running LargestFragmentChooser
# RDKit INFO: [21:26:08] Fragment: C=S(=O)(C(C)C)C1(C#N)C=NSN(C(=O)CC)CC1
# RDKit INFO: [21:26:08] New largest fragment: C=S(=O)(C(C)C)C1(C#N)C=NSN(C(=O)CC)CC1 (38)
# RDKit INFO: [21:26:08] Running LargestFragmentChooser
# RDKit INFO: [21:26:08] Fragment: Cc1cccc(C(=O)Cc2nc(Cl)cc3cccnc23)c1
# RDKit INFO: [21:26:08] New largest fragment: Cc1cccc(C(=O)Cc2nc(Cl)cc3cccnc23)c1 (34)
# RDKit INFO: [21:26:08] Running LargestFragmentChooser
# RDKit INFO: [21:26:08] Fragment: Cc1cccc(C(=O)Nc2cc(-c3ccccc3)no2)c1
# RDKit INFO: [21:26:08] New largest fragment: Cc1cccc(C(=O)Nc2cc(-c3ccccc3)no2)c1 (35)
# RDKit INFO: [21:26:08] Running LargestFragmentChooser
# RDKit INFO: [21:26:08] Fragment: Cc1cccc(C(=O)Cc2nc(Cc3ccco3)cs2)c1
# RDKit INFO: [21:26:08] New largest fragment: Cc1cccc(C(=O)Cc2nc(Cc3ccco3)cs2)c1 (36)
# RDKit INFO: [21:26:08] Running LargestFragmentChooser
# RDKit INFO: [21:26:08] Fragment: N#CCC1CCC2CCCN3CC=CC=CC=C1C2=CCOC#CNO3
# RDKit INFO: [21:26:08] New largest fragment: N#CCC1CCC2CCCN3CC=CC=CC=C1C2=CCOC#CNO3 (51)
# RDKit INFO: [21:26:08] Running LargestFragmentChooser
# RDKit INFO: [21:26:08] Fragment: N#CCC1CCC2CCCN3CC=CC=CC=C1C2=CCOC=CNO3
# RDKit INFO: [21:26:08] New largest fragment: N#CCC1CCC2CCCN3CC=CC=CC=C1C2=CCOC=CNO3 (53)
# RDKit INFO: [21:26:08] Running LargestFragmentChooser
# RDKit INFO: [21:26:08] Fragment: CNS(=O)(=O)N1CC2CCCC=Cc3ccccc3SC=CC=CC=CC2O1
# RDKit INFO: [21:26:08] New largest fragment: CNS(=O)(=O)N1CC2CCCC=Cc3ccccc3SC=CC=CC=CC2O1 (54)
# RDKit INFO: [21:26:08] Running LargestFragmentChooser
# RDKit INFO: [21:26:08] Fragment: CNON1CCCC2OC3OCCC(=CC=CC=CNC1)CCCCCC23
# RDKit INFO: [21:26:08] New largest fragment: CNON1CCCC2OC3OCCC(=CC=CC=CNC1)CCCCCC23 (62)
# RDKit INFO: [21:26:08] Running LargestFragmentChooser
# RDKit INFO: [21:26:08] Fragment: O=S1(=O)NCCCCCc2ccccc2SC=CC=CC=CC=C(Cl)CN1
# RDKit INFO: [21:26:08] New largest fragment: O=S1(=O)NCCCCCc2ccccc2SC=CC=CC=CC=C(Cl)CN1 (52)
# RDKit INFO: [21:26:08] Running LargestFragmentChooser
# RDKit INFO: [21:26:08] Fragment: O=C1CN(Cc2cccc(F)c2Nc2ncccn2)C(=O)c2cccc(c2)N1
# RDKit INFO: [21:26:08] New largest fragment: O=C1CN(Cc2cccc(F)c2Nc2ncccn2)C(=O)c2cccc(c2)N1 (44)
# RDKit INFO: [21:26:08] Running LargestFragmentChooser
# RDKit INFO: [21:26:08] Fragment: CC(=O)Nc1cccc(C(=O)N2Cc3ccccc3Nc3nc(C)nc(c3F)NN=C2C#N)c1
# ['CCC(=O)NCc1ccnn1[SH]1C=C(c2ccccc2F)NN1',
#  'CCC(=O)N1CC2C1CC2(C#N)S(=O)c1ccccn1',
#  'CCC(=O)N1c2ccn(-c3ncnc(C#N)c3C)c2[SH]1C']

# %%
def get_similarity(mol, smi_list):
    sim0 = mol
    sim1 = [Chem.MolFromSmiles(smiles) for smiles in smi_list]
    sim00 = Chem.RDKFingerprint(sim0)
    sim11 = [Chem.RDKFingerprint(x) for x in sim1]
    result = [TanimotoSimilarity(sim00,y) for y in sim11]
    return result

# %%
initial_mol[0]

# %%
first_structure_similarity = get_similarity(initial_mol[0], standarized_mols)

# %%
max(first_structure_similarity)
# Out:
# 0.29185185185185186

# %%
def get_similarity_lists_of_mols(mol_list, smi_list): #first list - mols, second smiles
    sim0 = mol_list
    sim1 = [Chem.MolFromSmiles(smiles) for smiles in smi_list]
    sim00 = [Chem.RDKFingerprint(x) for x in sim0]
    sim11 = [Chem.RDKFingerprint(x) for x in sim1]
    result = []
    for finger in sim00:
        for finger_2 in sim11:
            similarity = TanimotoSimilarity(finger,finger_2)
            result.append(similarity)
    return result

# %%
dataframe__ = get_similarity_lists_of_mols(initial_mol, standarized_mols)

# %%
dataframe = pd.DataFrame(dataframe__, columns=['Tanimoto similarity generated structures with ROR-y activ distribution'])

# %%
dataframe.hist()
print("MIN similarity: "+str(min(dataframe__)))
print("MAX similarity: "+str(max(dataframe__)))
# Out:
# MIN similarity: 0.13992172211350293
# MAX similarity: 1.0

# %%
plt.figure(figsize=(10,5))
plt.hist(dataframe['Tanimoto similarity generated structures with ROR-y activ distribution'],bins=100)
plt.xlabel('Tanimoto similarity', fontsize=14)
plt.ylabel('Frequency', fontsize=14)
#plt.title('Histogram of Tanimoto similarity distribution')
plt.grid(True)
plt.savefig("../prediction_and_selection/tmp/Tanimoto similarity generated structures with ROR-y activ distribution.svg")
plt.show()

print(dataframe['Tanimoto similarity generated structures with ROR-y activ distribution'].describe())
# Out:
# count    210.000000
# mean       0.266964
# std        0.095095
# min        0.139922
# 25%        0.213183
# 50%        0.247592
# 75%        0.284167
# max        1.000000
# Name: Tanimoto similarity generated structures with ROR-y activ distribution, dtype: float64

# %%
print(dataframe[dataframe['Tanimoto similarity generated structures with ROR-y activ distribution']<0.02].index.values)
# Out:
# []

# %%
dataframe[dataframe['Tanimoto similarity generated structures with ROR-y activ distribution']<0.02].head()
# Out:
# Empty DataFrame
# Columns: [Tanimoto similarity generated structures with ROR-y activ distribution]
# Index: []

# %% [markdown]
# ## Similarity among docked molecules

# %%
#docked_mols are at the beginning of the notebook

# %%
initial_docked_similarity = get_similarity_lists_of_mols(initial_mol, docked_mols)

# %%
dataframe_docked = pd.DataFrame(initial_docked_similarity, columns=['Tanimoto similarity among docked molecules distribution'])

# %%
dataframe_docked.hist()
print("MIN similarity: "+str(min(initial_docked_similarity)))
print("MAX similarity: "+str(max(initial_docked_similarity)))
# Out:
# MIN similarity: 0.13992172211350293
# MAX similarity: 1.0

# %%
list_to_be_ = []
list_to_be_
# Out:
# []

# %%
for mol in range(len(standarized_mols)): #comparision between generated mols
    simil = get_similarity(Chem.MolFromSmiles(standarized_mols[mol]), standarized_mols)
    list_to_be_.append(simil)

# %%
list_to_be_[0][0:5]
# Out:
# [1.0,
#  0.3179384203480589,
#  0.4188635032220269,
#  0.28144654088050314,
#  0.5684438040345822]

# %%
NEC = standarized_mols.copy()
KMV = standarized_mols.copy()

# %%
for elem in range(len(standarized_mols)):
    NEC[elem] = pd.DataFrame(list_to_be_[elem], columns=[standarized_mols[elem]])

# %%
frames = (NEC)

# %%
Final = pd.concat(frames, axis=1)
Final.head()
# Out:
#    CCC(=O)NCc1ccnn1[SH]1C=C(c2ccccc2F)NN1  \
# 0                                1.000000
# 1                                0.317938
# 2                                0.418864
# 3                                0.281447
# 4                                0.568444
#
#    CCC(=O)N1CC2C1CC2(C#N)S(=O)c1ccccn1  \
# 0                             0.317938
# 1                             1.000000
# 2                             0.395882
# 3                             0.272947
# 4                             0.338365
#
#    CCC(=O)N1c2ccn(-c3ncnc(C#N)c3C)c2[SH]1C  \
# 0                                 0.418864
# 1                                 0.395882
# 2                                 1.000000
# 3                                 0.275235
# 4                                 0.461495
#
#    CCC(=O)NCC1=NN=C(c2ccc(C)c(CF)c2)SC1  \
# 0                              0.281447
# 1                              0.272947
# 2                              0.275235
# 3                              1.000000
# 4                              0.266997
#
#    CCC(=O)NCc1ccnn1S1=C(C)NC(c2ccccc2F)=C1  \
# 0                                 0.568444
# 1                                 0.338365
# 2                                 0.461495
# 3                                 0.266997
# 4                                 1.000000
#
#    CCC(=O)NC1C=C2C=CC3CC=CC(=N3)N2C1C  CCC(=O)NCc1ccnn1N1NC2=C(NO)C1CC2C  \
# 0                            0.321233                           0.427774
# 1                            0.318373                           0.375229
# 2                            0.392836                           0.493929
# 3                            0.248784                           0.259868
# 4                            0.347097                           0.458531
#
#    CCC(=O)NCC=C1C=CNC(Cc2n[nH]c3c2CCO3)=N1  \
# 0                                 0.324176
# 1                                 0.303956
# 2                                 0.376623
# 3                                 0.250000
# 4                                 0.356957
#
#    CCC(=O)NCC1C(N)=NC1c1n[nH]cc1C(C)(C)O  \
# 0                               0.345788
# 1                               0.338877
# 2                               0.398007
# 3                               0.263283
# 4                               0.372675
#
#    CC(C1=CC=C[SH]1N)C1=NN=CC=CCNC(=O)CC1  ...  \
# 0                               0.248132  ...
# 1                               0.267396  ...
# 2                               0.297872  ...
# 3                               0.203756  ...
# 4                               0.288028  ...
#
#    CCC(=O)NC=CC(C)=NN([NH])c1c(F)cccc1Cl  Cc1cccc(C(=O)Cc2nc(Cc3ccoc3)cs2)c1  \
# 0                               0.235390                            0.242176
# 1                               0.220381                            0.247494
# 2                               0.232246                            0.291147
# 3                               0.207668                            0.225096
# 4                               0.245185                            0.261050
#
#    CC1=CC=CC(C(=O)Nc2cc(Cl)c(Cl)c(Cl)c2)=CO1  \
# 0                                   0.230649
# 1                                   0.227858
# 2                                   0.271208
# 3                                   0.197980
# 4                                   0.238742
#
#    CC1=CC=CC(CC(=O)N=S(C)c2ccc(Cl)cc2)=NO1  \
# 0                                 0.245342
# 1                                 0.235107
# 2                                 0.261307
# 3                                 0.198030
# 4                                 0.252131
#
#    N#CC1CCC2CCCCN3CNC=CC=CC=C1C2=C1OC1NO3  \
# 0                                0.305322
# 1                                0.307637
# 2                                0.350000
# 3                                0.206868
# 4                                0.314490
#
#    N#CC1C2=CC=C3OCNON4CC=CC=CC=C2C1CCCCC3C4  \
# 0                                  0.301779
# 1                                  0.301170
# 2                                  0.337927
# 3                                  0.198835
# 4                                  0.294271
#
#    N#CCC1CCC2CCCN3CC=CC=CC=C1C2=CC=C1OC1NO3  \
# 0                                  0.241911
# 1                                  0.241461
# 2                                  0.260788
# 3                                  0.175793
# 4                                  0.235007
#
#    CC(=O)Nc1cccc(C(=O)N2NC(F)=NNCC3C2Cc2cccc(CN)c2N3C)c1  \
# 0                                           0.405615
# 1                                           0.373882
# 2                                           0.496743
# 3                                           0.289370
# 4                                           0.469006
#
#    CC(=O)COCCC1=NC=CC(C(F)(F)F)=Nc2cnc[nH]nccc2OCCCOCCN1C  \
# 0                                           0.293447
# 1                                           0.286963
# 2                                           0.334937
# 3                                           0.234226
# 4                                           0.327285
#
#    CCC1=NCCc2cncn2-c2cc(F)ccc2CCN(C(=O)c2cccc(NC(C)=O)c2)NN1
# 0                                           0.383832
# 1                                           0.352642
# 2                                           0.469783
# 3                                           0.247207
# 4                                           0.442795
#
# [5 rows x 42 columns]

# %%
import matplotlib.pyplot as plt
plt.figure(figsize = (30, 20))
plt.imshow(Final, interpolation='nearest')
ax = plt.gca()
ax.set_xticks(range(0,len(standarized_mols),1))
ax.set_yticks(range(0,len(standarized_mols), 2))
plt.colorbar()
stg = Final.columns.values.tolist()
for i in range(len(standarized_mols)):
    for j in range(len(standarized_mols)):
        text = ax.text(j, i, round(Final[stg[i]][j],2), ha="center", va="center", color="w")
plt.savefig("../prediction_and_selection/tmp/heatmap_similarity_all_QED_LIP.svg")
plt.show()

# %%
## ASK if this should be present in master TH

# %% [markdown]
# ## Checking if the data created is very similar to training data

# %%
whole_data_set = pd.read_parquet('../model/data/zinc20_selected_to_create_model_processed.parquet')

# %%
whole_data_set.head()
# Out:
#         index                                       smiles  \
# 0   563932204       CNC(=O)CCCN1CCN(S(C)(=O)=O)[C@@H](C)C1
# 1    51885268  O=C(Cn1cc([N+](=O)[O-])cn1)N1CC[C@@H](CO)C1
# 2  1099938503     COCCCN1CC[C@@H](NC(=O)c2cnco2)[C@H](O)C1
# 3  1368537405  C[C@@H](O)CNC[C@H]1CN(C(=O)Cc2cnc[nH]2)CCO1
# 4  1379339000          C[C@H](CNCc1cn(C)nn1)NC(=O)COCC1CC1
#
#                                              SELFIES  SELFIES_length  \
# 0  [C][N][C][=Branch1][C][=O][C][C][C][N][C][C][N...              30
# 1  [O][=C][Branch1][S][C][N][C][=C][Branch1][=Bra...              30
# 2  [C][O][C][C][C][N][C][C][C@@H1][Branch1][=N][N...              30
# 3  [C][C@@H1][Branch1][C][O][C][N][C][C@H1][C][N]...              30
# 4  [C][C@H1][Branch1][=C][C][N][C][C][=C][N][Bran...              30
#
#                          SMILES_canonical  \
# 0       CNC(=O)CCCN1CCN(S(C)(=O)=O)C(C)C1
# 1  O=C(Cn1cc([N+](=O)[O-])cn1)N1CCC(CO)C1
# 2         COCCCN1CCC(NC(=O)c2cnco2)C(O)C1
# 3      CC(O)CNCC1CN(C(=O)Cc2cnc[nH]2)CCO1
# 4         CC(CNCc1cn(C)nn1)NC(=O)COCC1CC1
#
#                                    SELFIES_canonical  SELFIES_length_canonical
# 0  [C][N][C][=Branch1][C][=O][C][C][C][N][C][C][N...                        30
# 1  [O][=C][Branch1][S][C][N][C][=C][Branch1][=Bra...                        30
# 2  [C][O][C][C][C][N][C][C][C][Branch1][=N][N][C]...                        30
# 3  [C][C][Branch1][C][O][C][N][C][C][C][N][Branch...                        30
# 4  [C][C][Branch1][=C][C][N][C][C][=C][N][Branch1...                        30

# %% [markdown]
# ## Training was done on 121,000 of molecules
# ### Tanimoto simalirity distribution among newly generated and trained SMILES

# %%
whole_data_set = whole_data_set['SMILES_canonical']

# %%
len(whole_data_set)
# Out:
# 121000

# %%
whole_data_set_smi = [Chem.MolFromSmiles(smi) for smi in whole_data_set]

# %%
whole_data_set_smi[0]

# %%
#isomeric SMILES to canonical SMILES
whole_data_set_smi_cannonical = []
for mol in whole_data_set_smi:
    cannonical = Chem.MolToSmiles(mol, isomericSmiles=False)
    whole_data_set_smi_cannonical.append(cannonical)
whole_data_set_smi_cannonical[0:3]
# Out:
# ['CNC(=O)CCCN1CCN(S(C)(=O)=O)C(C)C1',
#  'O=C(Cn1cc([N+](=O)[O-])cn1)N1CCC(CO)C1',
#  'COCCCN1CCC(NC(=O)c2cnco2)C(O)C1']

# %%
whole_data_set_smi[0]

# %%
whole_data_set_smi_cannonical[0]
# Out:
# 'CNC(=O)CCCN1CCN(S(C)(=O)=O)C(C)C1'

# %%
whole_data_set_smi_cannonical_mol = [Chem.MolFromSmiles(smi) for smi in whole_data_set_smi_cannonical]
whole_data_set_smi_cannonical_mol[0]

# %%
df = get_similarity_lists_of_mols(whole_data_set_smi_cannonical_mol, docked_mols) #second param as list of SMILES

# %%
dataframe_train = pd.DataFrame(df, columns=['Tanimoto simalirity distribution among newly generated and trained SMILES'])

# %%
dataframe_train.hist()
print("MIN similarity: "+str(min(df)))
print("MAX similarity: "+str(max(df)))
# Out:
# MIN similarity: 0.023952095808383235
# MAX similarity: 0.6454682023034551

# %%
plt.figure(figsize=(10,5))
plt.hist(dataframe_train['Tanimoto simalirity distribution among newly generated and trained SMILES'],bins=100)
plt.xlabel('Tanimoto similarity', fontsize=14)
plt.ylabel('Frequency', fontsize=14)
#plt.title('Histogram of Tanimoto similarity distribution')
#plt.axvline(x=0.0, color='r')
plt.grid(True)
plt.savefig("../prediction_and_selection/tmp/Tanimoto simalirity distribution among newly generated and trained SMILES V1.svg")
plt.show()

print(dataframe_train['Tanimoto simalirity distribution among newly generated and trained SMILES'].describe())
# Out:
# count    5.082000e+06
# mean     2.484944e-01
# std      6.081470e-02
# min      2.395210e-02
# 25%      2.040976e-01
# 50%      2.418136e-01
# 75%      2.867967e-01
# max      6.454682e-01
# Name: Tanimoto simalirity distribution among newly generated and trained SMILES, dtype: float64

# %%
new_ = dataframe_train[dataframe_train['Tanimoto simalirity distribution among newly generated and trained SMILES']>0.5]

# %%
len(new_['Tanimoto simalirity distribution among newly generated and trained SMILES'])
# Out:
# 983

# %% [markdown]
# ## Check if initial SMILES is present in PUBCHEM database (ROR-y activ)

# %%
def find_smiles_in_PUBCHEM(smiles):
    compounds = []
    try:
        compound = pcp.get_compounds(smiles, 'smiles')
        compounds.append(compound)
    except:
        print("Not found : "+ str(smiles))
    return compounds

# %%
test_if_initial_data_can_be_found = [find_smiles_in_PUBCHEM(smiles) for smiles in initial_smi['SMILES']]

# %%
test_if_initial_data_can_be_found
# Out:
# [[[Compound(807146)]],
#  [[Compound(16445174)]],
#  [[Compound(71470549)]],
#  [[Compound(71811962)]],
#  [[Compound(135337558)]]]

# %% [markdown]
# ## Check if newly generated SMILES is present in PUBCHEM database

# %%
test_if_newly_generated_data_can_be_found = [find_smiles_in_PUBCHEM(smiles) for smiles in to_check_in_PUBCHEM]
# Out:
# Not found : CCC(=O)NCc1ccnn1[SH]1C=C(c2ccccc2F)NN1
# Not found : CCC(=O)N1c2ccn(-c3ncnc(C#N)c3C)c2[SH]1C
# Not found : CC(C1=CC=C[SH]1N)C1=NN=CC=CCNC(=O)CC1

# %%
test_if_newly_generated_data_can_be_found
# Out:
# [[],
#  [[Compound()]],
#  [],
#  [[Compound()]],
#  [[Compound()]],
#  [[Compound()]],
#  [[Compound()]],
#  [[Compound()]],
#  [[Compound()]],
#  [],
#  [[Compound()]],
#  [[Compound()]],
#  [[Compound()]],
#  [[Compound()]],
#  [[Compound(16445174)]],
#  [[Compound()]],
#  [[Compound()]],
#  [[Compound()]],
#  [[Compound()]],
#  [[Compound()]],
#  [[Compound()]],
#  [[Compound()]],
#  [[Compound()]],
#  [[Compound()]],
#  [[Compound()]],
#  [[Compound()]],
#  [[Compound()]],
#  [[Compound()]],
#  [[Compound()]],
#  [[Compound()]],
#  [[Compound()]],
#  [[Compound()]],
#  [[Compound()]],
#  [[Compound()]],
#  [[Compound()]],
#  [[Compound()]],
#  [[Compound()]],
#  [[Compound()]],
#  [[Compound()]],
#  [[Compound()]],
#  [[Compound()]],
#  [[Compound()]]]
